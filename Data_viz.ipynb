# %% [markdown]
# # SAE_Analyse_De_Donnee_&_Reporting_Viz

# %%
import pandas as pd
import numpy as np

# %%
sncf = pd.read_excel("DonneesSNCF.xlsx")

# %%
sncf
# Out:
#                      GARE  CODE_DEP  CODE_INSEE  CODE_UIC  CODE_POSTAL  \
# 0       Ambérieu-en-Bugey         1        1004  87743716         1500
# 1        Ambronay - Priay         1        1007  87743146         1500
# 2      Tenay - Hauteville         1        1017  87743757         1970
# 3             La Valbonne         1        1027  87723577         1360
# 4               Bellignat         1        1031  87743526         1810
# ...                   ...       ...         ...       ...          ...
# 2792            Vaucelles        95       95607  87276626        95150
# 2793              Taverny        95       95607  87276634        95150
# 2794                   Us        95       95625  87381178        95450
# 2795              Viarmes        95       95652  87276568        95270
# 2796  Villaines-sous-Bois        95       95660  87272021        95570
#
#           LONG        LAT  NB_VOY_2022   NB_VOY_2021   NB_VOY_2020   ...  \
# ...

# %%
sncf.isnull().sum()
# Out:
# GARE                    0
# CODE_DEP                0
# CODE_INSEE              0
# CODE_UIC                0
# CODE_POSTAL             0
#                        ..
# DepT INTERCITES_2018    0
# DepT INTERCITES_2019    0
# DepT INTERCITES_2020    0
# DepT INTERCITES_2021    0
# DepT INTERCITES_2022    0
# Length: 76, dtype: int64
